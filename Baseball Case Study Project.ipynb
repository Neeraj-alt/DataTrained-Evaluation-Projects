# %% [markdown]
# # Baseball Case Study Project

# %% [markdown]
# Importing the impotatnt libraries for data loading, manipulation and visulization.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Loading the data

# %%
df=pd.read_csv('baseball.csv')
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# We have 30 rows and 17 columns in the dataset.

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# There is no ull value presents.

# %%
df.columns
# Out:
# Index(['W', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'RA', 'ER',
#        'ERA', 'CG', 'SHO', 'SV', 'E'],
#       dtype='object')

# %% [markdown]
# Columns description:
# W- Number of wins
#
# R- Runs
#
# AB- At Bats
#
# H- Hits
#
# 2B- Doubles
#
# 3B- Triples
#
# HR- Homeruns
#
# BB- Walks
#
# SO- Strikeouts
#
# SB- Stolen Bases
#
# RA- Runs Allowed
#
# ER- Earned Runs
#
# ERA-Earned Run Average
#
# CG- Complete Games
#
# SHO-Shutouts
#
# SV- Saves
#
# E- Errors

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# All features are numerical with only 1 feature 'ERA' as float

# %%
df.describe().transpose()
# Out:
#      count         mean         std      min        25%       50%      75%  \
# W     30.0    80.966667   10.453455    63.00    74.0000    81.000    87.75
# R     30.0   688.233333   58.761754   573.00   651.2500   689.000   718.25
# AB    30.0  5516.266667   70.467372  5385.00  5464.0000  5510.000  5570.00
# H     30.0  1403.533333   57.140923  1324.00  1363.0000  1382.500  1451.50
# 2B    30.0   274.733333   18.095405   236.00   262.2500   275.500   288.75
# 3B    30.0    31.300000   10.452355    13.00    23.0000    31.000    39.00
# HR    30.0   163.633333   31.823309   100.00   140.2500   158.500   177.00
# BB    30.0   469.100000   57.053725   375.00   428.2500   473.000   501.25
# SO    30.0  1248.200000  103.759470   973.00  1157.5000  1261.500  1311.50
# SB    30.0    83.500000   22.815225    44.00    69.0000    83.500    96.50
# RA    30.0   688.233333   72.108005   525.00   636.2500   695.500   732.50
# ER    30.0   635.833333   70.140786   478.00   587.2500   644.500   679.25
# ERA   30.0     3.956333    0.454089     2.94     3.6825     4.025     4.22
# CG    30.0     3.466667    2.763473     0.00     1.0000     3.000     5.75
# SHO   30.0    11.300000    4.120177     4.00     9.0000    12.000    13.00
# SV    30.0    43.066667    7.869335    28.00    37.2500    42.000    46.75
# E     30.0    94.333333   13.958889    75.00    86.0000    91.000    96.75
#
#          max
# W     100.00
# R     891.00
# AB   5649.00
# H    1515.00
# 2B    308.00
# 3B     49.00
# HR    232.00
# BB    570.00
# SO   1518.00
# SB    134.00
# RA    844.00
# ER    799.00
# ERA     5.04
# CG     11.00
# SHO    21.00
# SV     62.00
# E     126.00

# %% [markdown]
# We see the  Min number of wins 63 and max is 100. Min number of Runs scored by a team is 573 and max is 891 with an average of 688 runs in 2014 season.There were min 100 home runs scored by a team and max of 232 with an average of 163 home run scored by a team.Strikeouts ranges from 973 to 1518 with an average of 1248.

# %%
for i in df.columns:
    sns.lineplot(x='W',y=i,data=df)
    plt.show()

# %% [markdown]
# From above line polts we can conclude that number of win increases with the decrease in Runs Allowed(RA),Earned Runs(ER) and Earned Run Average (ERA).
#
# Chances of win increases with the increae in Walks(BB), Shutouts(SHO) and Saves(SV)
#
# Let's study this with scatter plot

# %%
sns.scatterplot(x='W',y='SV',data=df)
# Out:
# <AxesSubplot:xlabel='W', ylabel='SV'>

# %% [markdown]
# We can see that number of Saves increases the chance of Win

# %%
sns.scatterplot(x='RA',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='RA', ylabel='W'>

# %% [markdown]
# More runs allowed will decrease the chances of winning.

# %%
sns.scatterplot(x='HR',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='HR', ylabel='W'>

# %% [markdown]
# Home Run does have minor impact in winning most number of matches

# %%
sns.scatterplot(x='2B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='2B', ylabel='W'>

# %% [markdown]
# Scoring huigh number of doubles can improve the chances of winning

# %%
sns.scatterplot(x='3B',y='W',data=df)
# Out:
# <AxesSubplot:xlabel='3B', ylabel='W'>

# %% [markdown]
# 3B has no coreralion in winning the number of matches

# %% [markdown]
# # Checking for outliers and skewness

# %%
for i in df.columns:
    sns.boxplot(df[i])
    plt.show()

# %% [markdown]
# There are outliers in R and few outliers in E. Hence there are not much outliers present in the dataset. Since our dataset is small we will not remove them
#
# Checking for outliers in R

# %%
df[df['R']>850]
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER  ERA  CG  SHO  \
# 5  93  891  5509  1480  308  17  232  570  1151  88  670  609  3.8   7   10
#
#    SV   E
# 5  34  88

# %% [markdown]
# As we can see as there is only 1 team that has scored more than 891 runs
#
# Checking for outliers in E

# %%
df[df['E']>120]
# Out:
#      W    R    AB     H   2B  3B   HR   BB    SO  SB   RA   ER   ERA  CG  SHO  \
# 14  68  694  5600  1405  277  46  146  475  1119  78  729  664  4.14   5   15
# 16  98  697  5631  1462  292  27  140  461  1322  98  596  532  3.21   0   13
#
#     SV    E
# 14  28  126
# 16  54  122

# %% [markdown]
# Here also hardly any data above 120 so we will keep the outliers
#
# Checking the skewness

# %%
df.skew()
# Out:
# W      0.047089
# R      1.200786
# AB     0.183437
# H      0.670254
# 2B    -0.230650
# 3B     0.129502
# HR     0.516441
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG     0.736845
# SHO    0.565790
# SV     0.657524
# E      0.890132
# dtype: float64

# %% [markdown]
# We will use th log transform method to remove the skewness.

# %%
for i in df.columns:
    if df[i].skew()>0.50:
        df[i]=np.log1p(df[i])

# %%
df.skew()
# Out:
# W      0.047089
# R      0.744813
# AB     0.183437
# H      0.628584
# 2B    -0.230650
# 3B     0.129502
# HR    -0.009528
# BB     0.158498
# SO    -0.156065
# SB     0.479893
# RA     0.045734
# ER     0.058710
# ERA    0.053331
# CG    -0.325962
# SHO   -0.589640
# SV     0.163057
# E      0.632916
# dtype: float64

# %% [markdown]
# We are able to reduce the skewness in most of the features. Using other skew method were returning Null values

# %%
df
# Out:
#       W         R    AB         H   2B  3B        HR   BB    SO   SB   RA  \
# 0    95  6.586172  5575  7.311886  300  42  4.941642  383   973  104  641
# 1    83  6.546785  5467  7.207860  277  44  5.056246  439  1264   70  700
# 2    81  6.507278  5439  7.241366  303  29  4.955827  533  1157   86  640
# 3    76  6.434547  5533  7.231287  260  27  4.919981  404  1231   68  701
# 4    74  6.536692  5605  7.323831  289  49  5.023881  455  1259   83  803
# 5    93  6.793466  5509  7.300473  308  17  5.451038  570  1151   88  670
# 6    87  6.639876  5567  7.242798  272  19  5.361292  554  1227   63  698
# 7    81  6.570883  5485  7.223296  246  20  5.384495  418  1331   44  693
# 8    80  6.469250  5485  7.232733  278  32  5.123964  436  1310   87  642
# 26  597  3.72  2.079442  2.944439  3.737670  4.369448
# 27  659  4.04  0.693147  2.564949  3.806662  4.465908
# 28  655  4.09  0.693147  1.945910  3.737670  4.532599
# 29  799  5.04  1.609438  1.609438  3.610918  4.564348

# %% [markdown]
# # Model Fitting

# %% [markdown]
# Let's split the data into input and target variable

# %%
x=df.drop(['W'],axis=1)
y=df['W']
y=pd.DataFrame(data=y)

# %% [markdown]
# Before fitting our model, first we will bring the data to common scale using Standard Scaler

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
sc_x=sc.fit_transform(x)
sc_x=pd.DataFrame(sc_x,columns=x.columns)

# %%
sc_x
# Out:
#            R        AB         H        2B        3B        HR        BB  \
# 0   0.665329  0.847731  1.649382  1.420173  1.041193 -0.763978 -1.534902
# 1   0.179562 -0.711094 -0.981656  0.127403  1.235809 -0.157077 -0.536592
# 2  -0.307704 -1.115233 -0.134210  1.588795 -0.223808 -0.688861  1.139144
# 3  -1.204730  0.241522 -0.389136 -0.828122 -0.418423 -0.878690 -1.160536
# 4   0.055070  1.280738  1.951480  0.801892  1.722347 -0.328473 -0.251360
# 5   3.221983 -0.104884  1.360715  1.869832 -1.391501  1.933613  1.798742
# 6   1.327687  0.732263 -0.098001 -0.153633 -1.196885  1.458347  1.513510
# 7   0.476767 -0.451289 -0.591253 -1.615025 -1.099578  1.581221 -0.910958
# 8  -0.776713 -0.451289 -0.352560  0.183611  0.068115  0.201536 -0.590073
# 9   1.066997  1.785913  1.615591  1.082929  0.165423  0.008945  0.158660
# 10  1.116298 -0.076017  0.296915  0.239818  0.068115  0.356845  0.604334
# 11  0.750096 -0.826562 -0.720719  0.183611 -0.515731  1.887960  0.301276
# 12 -0.455855 -1.432772 -1.321151 -1.783647 -1.002270  0.477894 -0.607900
# 13 -0.549362  0.400291 -0.425764 -0.715707 -0.904962  1.098308  0.158660
# 14  0.144121  1.208570  0.046319  0.127403  1.430424 -0.505602  0.105179
# 15 -0.719481 -0.465723 -0.297796  0.745685  0.749270 -0.840176  0.657815
# 16  0.197244  1.656011  1.051433  0.970514 -0.418423 -0.726286 -0.144398
# 17  0.055070 -0.364688 -1.131980 -0.153633 -0.126500  0.326146  1.745261
# 18 -0.568148 -0.523457 -0.444099 -0.041219  0.262731 -0.541750 -1.017920
# 19 -0.853437  0.789997 -0.370841 -0.996744 -0.418423  0.201536  0.479546
# 20 -0.052646  0.154920 -0.944214  1.139136 -1.391501  0.507729  0.336930
# 21  0.302809 -1.274002 -0.720719 -0.547085 -1.780732  0.507729  1.246105
# 22 -1.384201 -0.768828  0.314720 -2.177099  0.846578 -1.536361 -1.677518
# 23 -2.215049 -1.389471 -0.757831 -1.333988 -1.294193 -2.493129  0.033871
# 24 -1.125795  0.183787 -0.517569 -0.153633  0.554654 -1.115849 -1.463595
# 25 -0.344575 -1.894646 -1.037923 -0.659500 -0.515731  0.797182  1.673953
# 26  0.179562  0.703396  1.462974  0.745685  0.749270 -0.878690 -0.215706
# 27  0.597094  1.915815  1.598679  0.801892  1.625040 -0.224971  0.372584
# 28 -0.662513 -0.855429 -1.454418 -0.828122  0.457346 -0.434038 -0.768343
# 15  2.162463  0.196422
# 16  1.373857  1.916564
# 17  0.703068  1.237952
# 18 -0.332028  1.554313
# 19 -1.087253 -0.266087
# 20  0.935381 -0.427060
# 21 -0.192092 -0.266087
# 22 -1.087253 -1.382679
# 23  0.208552 -0.266087
# 24 -1.087253  1.615960
# 25  0.583331 -1.570833
# 26 -0.192092 -1.290404
# 27  0.208552 -0.591693
# 28 -0.192092 -0.108613
# 29 -0.928146  0.121359

# %% [markdown]
# Let's import the necessary Regression libraries for model fitting.

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.linear_model import Lasso,Ridge,ElasticNet
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import KFold

# %% [markdown]
# We will use Linear regression model to check for the best random state to fit our training and test data

# %%
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state {i},the training accuracy is: {r2_score(y_train,pred_train)}')
    print(f'At random state {i},the testing accuracy is: {r2_score(y_test,pred_test)}')
    print('\n')
# Out:
# At random state 0,the training accuracy is: 0.9679448816086823
# At random state 0,the testing accuracy is: -0.04970224427323289
#
#
# At random state 1,the training accuracy is: 0.9675887780905523
# At random state 1,the testing accuracy is: 0.7638525513628693
#
#
# At random state 2,the training accuracy is: 0.9878077044194704
# At random state 2,the testing accuracy is: -1.6709380618954688
#
#
# At random state 3,the training accuracy is: 0.9618549437307777
# At random state 3,the testing accuracy is: 0.585735901671398
#
#
# At random state 4,the training accuracy is: 0.9671574119519999
# At random state 4,the testing accuracy is: 0.5937383632226554
#
#
# At random state 5,the training accuracy is: 0.9493963547470089
# At random state 5,the testing accuracy is: 0.8851590912293595
#
#
# At random state 6,the training accuracy is: 0.9586627943801213
# At random state 6,the testing accuracy is: 0.7651451623519188
#
#
# At random state 7,the training accuracy is: 0.9633805510461999
# At random state 7,the testing accuracy is: -0.12218163389795711
#
#
# At random state 8,the training accuracy is: 0.9631050422921924
# At random state 8,the testing accuracy is: 0.7014456433520178
#
#
# At random state 9,the training accuracy is: 0.9539949629068536
# At random state 9,the testing accuracy is: 0.838706055976326
#
#
# At random state 10,the training accuracy is: 0.9678779743453917
# At random state 10,the testing accuracy is: 0.09063917953931266
#
#
# At random state 11,the training accuracy is: 0.97428571956856
# At random state 11,the testing accuracy is: -0.9743823246565047
#
#
# At random state 12,the training accuracy is: 0.9733835071810315
# At random state 12,the testing accuracy is: -0.18937838358814774
#
#
# At random state 13,the training accuracy is: 0.9658011756630577
# At random state 13,the testing accuracy is: 0.7643946512935802
#
#
# At random state 14,the training accuracy is: 0.9526868916971454
# At random state 14,the testing accuracy is: 0.7711110637859205
#
#
# At random state 15,the training accuracy is: 0.9643286378290145
# At random state 15,the testing accuracy is: 0.39524227453146754
#
#
# At random state 16,the training accuracy is: 0.9798920780942693
# At random state 16,the testing accuracy is: 0.03831534844056439
#
#
# At random state 17,the training accuracy is: 0.974142380329922
# At random state 17,the testing accuracy is: 0.45992787496922904
#
#
# At random state 18,the training accuracy is: 0.958675959241927
# At random state 18,the testing accuracy is: 0.6562745266354459
#
#
# At random state 19,the training accuracy is: 0.9522109036298314
# At random state 19,the testing accuracy is: 0.8603238042944193
#
#
# At random state 20,the training accuracy is: 0.9692259365270851
# At random state 20,the testing accuracy is: -0.08845196766793273
#
#
# At random state 21,the training accuracy is: 0.9673408069655514
# At random state 21,the testing accuracy is: 0.5132888796296315
#
#
# At random state 22,the training accuracy is: 0.9707642086701829
# At random state 22,the testing accuracy is: -0.9022470456430982
#
#
# At random state 23,the training accuracy is: 0.9683095192126224
# At random state 23,the testing accuracy is: 0.5897073879899524
#
#
# At random state 24,the training accuracy is: 0.9836435264295388
# At random state 24,the testing accuracy is: -2.7018010648753505
#
#
# At random state 25,the training accuracy is: 0.9621648551152961
# At random state 25,the testing accuracy is: 0.6148108652502058
#
#
# At random state 26,the training accuracy is: 0.9773655277847116
# At random state 26,the testing accuracy is: -0.09453859413095556
#
#
# At random state 27,the training accuracy is: 0.9599118943112838
# At random state 27,the testing accuracy is: 0.8070622329383619
#
#
# At random state 28,the training accuracy is: 0.9676118676155087
# At random state 28,the testing accuracy is: 0.4225239415741069
#
#
# At random state 29,the training accuracy is: 0.9586184567880892
# At random state 29,the testing accuracy is: 0.8637396327428424
#
#
# At random state 30,the training accuracy is: 0.9595198743400984
# At random state 30,the testing accuracy is: 0.41608198635841553
#
#
# At random state 31,the training accuracy is: 0.9875677941773606
# At random state 31,the testing accuracy is: 0.0657371986850116
#
#
# At random state 32,the training accuracy is: 0.9662588961634161
# At random state 32,the testing accuracy is: 0.25216591743796113
#
#
# At random state 33,the training accuracy is: 0.9784716955252711
# At random state 33,the testing accuracy is: 0.7190961667396163
#
#
# At random state 34,the training accuracy is: 0.9683192709763766
# At random state 34,the testing accuracy is: 0.8063491360921273
#
#
# At random state 35,the training accuracy is: 0.9725842795212993
# At random state 35,the testing accuracy is: 0.5178808090424785
#
#
# At random state 36,the training accuracy is: 0.9667412215885239
# At random state 36,the testing accuracy is: 0.6695289149156494
#
#
# At random state 37,the training accuracy is: 0.9532094705803782
# At random state 37,the testing accuracy is: 0.7887274907315718
#
#
# At random state 38,the training accuracy is: 0.9705740262059954
# At random state 38,the testing accuracy is: 0.195775910154791
#
#
# At random state 39,the training accuracy is: 0.951157232197651
# At random state 39,the testing accuracy is: 0.9268810363655625
#
#
# At random state 40,the training accuracy is: 0.9596726713177616
# At random state 40,the testing accuracy is: 0.5754314579125317
#
#
# At random state 41,the training accuracy is: 0.9556027326757874
# At random state 41,the testing accuracy is: 0.8351144201308083
#
#
# At random state 42,the training accuracy is: 0.9725264700007623
# At random state 42,the testing accuracy is: 0.8074705565423528
#
#
# At random state 43,the training accuracy is: 0.9776416597133083
# At random state 43,the testing accuracy is: -0.6604942449931674
#
#
# At random state 44,the training accuracy is: 0.9614544137318692
# At random state 44,the testing accuracy is: 0.7127448003958101
#
#
# At random state 45,the training accuracy is: 0.9549857925732338
# At random state 45,the testing accuracy is: 0.7716510498093646
#
#
# At random state 46,the training accuracy is: 0.9713278474863041
# At random state 46,the testing accuracy is: 0.2174624317273154
#
#
# At random state 47,the training accuracy is: 0.9666953223858832
# At random state 47,the testing accuracy is: 0.646087930250125
#
#
# At random state 48,the training accuracy is: 0.95164120901052
# At random state 48,the testing accuracy is: 0.7438145082565821
#
#
# At random state 49,the training accuracy is: 0.9837027505044574
# At random state 49,the testing accuracy is: 0.10996193028213253
#
#
# At random state 50,the training accuracy is: 0.9840431891947025
# At random state 50,the testing accuracy is: 0.6151968985201632
#
#
# At random state 51,the training accuracy is: 0.9751736726259651
# At random state 51,the testing accuracy is: 0.4571237761786925
#
#
# At random state 52,the training accuracy is: 0.9713313294401279
# At random state 52,the testing accuracy is: 0.5407881348878196
#
#
# At random state 53,the training accuracy is: 0.9762037526374033
# At random state 53,the testing accuracy is: 0.43871874724962867
#
#
# At random state 54,the training accuracy is: 0.9685251187184252
# At random state 54,the testing accuracy is: 0.6881777582573009
#
#
# At random state 55,the training accuracy is: 0.9578540139578117
# At random state 55,the testing accuracy is: 0.8212429084283711
#
#
# At random state 56,the training accuracy is: 0.9675187601687313
# At random state 56,the testing accuracy is: 0.05595209089696063
#
#
# At random state 57,the training accuracy is: 0.9720838784255504
# At random state 57,the testing accuracy is: -0.34384664628411055
#
#
# At random state 58,the training accuracy is: 0.9629208440885344
# At random state 58,the testing accuracy is: 0.3049652674891602
#
#
# At random state 59,the training accuracy is: 0.9801136465356362
# At random state 59,the testing accuracy is: -0.2262987434931214
#
#
# At random state 60,the training accuracy is: 0.9821218853058682
# At random state 60,the testing accuracy is: -0.6683897301574022
#
#
# At random state 61,the training accuracy is: 0.9786595921149785
# At random state 61,the testing accuracy is: 0.032075832863961984
#
#
# At random state 62,the training accuracy is: 0.9632478707922781
# At random state 62,the testing accuracy is: 0.5208177170761574
#
#
# At random state 63,the training accuracy is: 0.9610262190108072
# At random state 63,the testing accuracy is: 0.7204216689795622
#
#
# At random state 64,the training accuracy is: 0.9526321340841214
# At random state 64,the testing accuracy is: 0.8203466071478311
#
#
# At random state 65,the training accuracy is: 0.9563267556189617
# At random state 65,the testing accuracy is: 0.7314077746071792
#
#
# At random state 66,the training accuracy is: 0.9854913241706108
# At random state 66,the testing accuracy is: 0.18113158542303287
#
#
# At random state 67,the training accuracy is: 0.9544741981366637
# At random state 67,the testing accuracy is: 0.7931758493344059
#
#
# At random state 68,the training accuracy is: 0.9484876250159837
# At random state 68,the testing accuracy is: 0.7061106974379102
#
#
# At random state 69,the training accuracy is: 0.9570399640468776
# At random state 69,the testing accuracy is: 0.8111751913774384
#
#
# At random state 70,the training accuracy is: 0.9725586666323752
# At random state 70,the testing accuracy is: -1.582905015190692
#
#
# At random state 71,the training accuracy is: 0.9728799000403825
# At random state 71,the testing accuracy is: -0.5591972747303044
#
#
# At random state 72,the training accuracy is: 0.9637985836648735
# At random state 72,the testing accuracy is: 0.702205482465039
#
#
# At random state 73,the training accuracy is: 0.968914621709717
# At random state 73,the testing accuracy is: 0.709882052032452
#
#
# At random state 74,the training accuracy is: 0.9809540976647357
# At random state 74,the testing accuracy is: -0.6098373851081778
#
#
# At random state 75,the training accuracy is: 0.9580162032438847
# At random state 75,the testing accuracy is: 0.5822996688084878
#
#
# At random state 76,the training accuracy is: 0.9786991626719804
# At random state 76,the testing accuracy is: -0.31939031680501606
#
#
# At random state 77,the training accuracy is: 0.983265854176815
# At random state 77,the testing accuracy is: -0.2617543728233236
#
#
# At random state 78,the training accuracy is: 0.9674664375104562
# At random state 78,the testing accuracy is: 0.5964537583037222
#
#
# At random state 79,the training accuracy is: 0.9693209059817748
# At random state 79,the testing accuracy is: 0.33985109651560086
#
#
# At random state 80,the training accuracy is: 0.9751918141364685
# At random state 80,the testing accuracy is: 0.18765141945818997
#
#
# At random state 81,the training accuracy is: 0.9744549165821933
# At random state 81,the testing accuracy is: -4.776966316151914
#
#
# At random state 82,the training accuracy is: 0.9730839807238361
# At random state 82,the testing accuracy is: 0.7727827480794272
#
#
# At random state 83,the training accuracy is: 0.9549758741356452
# At random state 83,the testing accuracy is: 0.8472819479773149
#
#
# At random state 84,the training accuracy is: 0.9524539685584126
# At random state 84,the testing accuracy is: 0.740320105267975
#
#
# At random state 85,the training accuracy is: 0.9641708203455135
# At random state 85,the testing accuracy is: 0.8258571617691177
#
#
# At random state 86,the training accuracy is: 0.9532641719920669
# At random state 86,the testing accuracy is: 0.7792446545458214
#
#
# At random state 87,the training accuracy is: 0.9722139503605026
# At random state 87,the testing accuracy is: 0.23932645692108867
#
#
# At random state 88,the training accuracy is: 0.9747088436809412
# At random state 88,the testing accuracy is: -2.2275110129278235
#
#
# At random state 89,the training accuracy is: 0.9777778358548829
# At random state 89,the testing accuracy is: -0.7123712319439277
#
#
# At random state 90,the training accuracy is: 0.9572504881491077
# At random state 90,the testing accuracy is: 0.8686872916083472
#
#
# At random state 91,the training accuracy is: 0.9514701597463877
# At random state 91,the testing accuracy is: 0.8068969738497133
#
#
# At random state 92,the training accuracy is: 0.9680390085630007
# At random state 92,the testing accuracy is: 0.6271722664524275
#
#
# At random state 93,the training accuracy is: 0.9702739499274651
# At random state 93,the testing accuracy is: 0.3906889154060942
#
#
# At random state 94,the training accuracy is: 0.9748529124613425
# At random state 94,the testing accuracy is: -0.28532484636375566
#
#
# At random state 95,the training accuracy is: 0.9633020950006765
# At random state 95,the testing accuracy is: 0.48301037438592487
#
#
# At random state 96,the training accuracy is: 0.9669807439112569
# At random state 96,the testing accuracy is: 0.4893941999494458
#
#
# At random state 97,the training accuracy is: 0.9547449774565522
# At random state 97,the testing accuracy is: 0.7885531527021852
#
#
# At random state 98,the training accuracy is: 0.9731392425805842
# At random state 98,the testing accuracy is: 0.6428222032278488
#
#
# At random state 99,the training accuracy is: 0.9647546054075982
# At random state 99,the testing accuracy is: 0.8498060877709178

# %% [markdown]
# We will now split the data with the random_state 39 as that has given us the best accuracy on training and test data.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=39)

# %% [markdown]
# # Fitting the data to SupportVectorRegression model

# %%
from sklearn.svm import SVR
kernellist=['linear','poly','rbf']
for i in kernellist:
    sv=SVR(kernel=i)
    sv.fit(x_train,y_train)
    print(sv.score(x_train,y_train))
# Out:
# 0.8962933961064962
# 0.4813617606259595
# 0.25090856293346386

# %% [markdown]
# Kernel 'linear' has given us the best output.

# %% [markdown]
# # Fitting the data to various model and checking the accuracy

# %%
sv=SVR(kernel='linear')
dt=DecisionTreeRegressor()
rf=RandomForestRegressor()
kn=KNeighborsRegressor()
ab=AdaBoostRegressor()
ls=Lasso()
rd=Ridge()

model=[lr,sv,dt,rf,kn,ab,ls,rd]
kf = KFold(n_splits=5, random_state=54, shuffle=True)

train=[]
test=[]
Mse=[]
cv=[]

for m in model:
    m.fit(x_train,y_train)
    pred_train=m.predict(x_train)
    pred_test=m.predict(x_test)
    train_score=r2_score(y_train,pred_train)
    train.append(train_score)
    test_score=r2_score(y_test,pred_test)
    test.append(test_score)
    mse = mean_squared_error(y_test,pred_test)
    Mse.append(mse)
    score=cross_val_score(m,x,y,cv=kf)
    cv.append(score.mean())
    
Performance={'Model':['Linear Regression','SupportVector','DecisionTree','RandomForest','KNN','AdaBoost','Lasso','Ridge'],
             'Training Score':train,
            'Test Score':test,
            'Mean Square Error':Mse,
            'Cross Validation Score': cv}
Performance=pd.DataFrame(data=Performance)
Performance
# Out:
#                Model  Training Score  Test Score  Mean Square Error  \
# 0  Linear Regression        0.951157    0.926881           8.067459
# 1      SupportVector        0.896293    0.845364          17.061464
# 2       DecisionTree        1.000000    0.358006          70.833333
# 3       RandomForest        0.934349    0.420905          63.893450
# 4                KNN        0.667355    0.395831          66.660000
# 5           AdaBoost        0.991097    0.511198          53.931126
# 6              Lasso        0.878584    0.807420          21.247940
# 7              Ridge        0.934004    0.903783          10.615963
#
#    Cross Validation Score
# 0                0.302692
# 1                0.497753
# 2               -0.735958
# 3                0.267276
# 4                0.377956
# 5                0.238075
# 6                0.670743
# 7                0.515796

# %% [markdown]
# From the above table we can say that Lasso is best that fits the model. It has accuracy score of 80% and CV score of 67%. It has shown the minimum difference.

# %% [markdown]
# # HyperTuning Lasso

# %% [markdown]
# For hypertuning we will usee GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'alpha':[.0001,.001,.01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train,y_train)

print(clf.best_params_)
# Out:
# {'alpha': 1, 'random_state': 0}

# %% [markdown]
# Lets fit the above parameters to the Lasso

# %%
ls=Lasso(alpha=1,random_state=0)
ls.fit(x_train,y_train)
pred_ls=ls.predict(x_test)
lss=r2_score(y_test,pred_ls)
scores=cross_val_score(ls,x,y,cv=kf)
MSE = mean_squared_error(y_test,pred_ls)
print('Lasso Performance')
print('---------------------------------------------------')
print('Accuracy Score', lss)
print('Cross Validation score',scores.mean())
print('Mean Square Error',mse)
# Out:
# Lasso Performance
# ---------------------------------------------------
# Accuracy Score 0.8074204840529899
# Cross Validation score 0.6707429491489165
# Mean Square Error 10.615963407213583

# %% [markdown]
# ChoosING this as our final model

# %% [markdown]
# # Visualizing our model

# %%
plt.figure(figsize=(8,6))
plt.scatter(x=y_test,y=pred_ls,color='r')
plt.plot(y_test,y_test,color='b')
plt.xlabel('Actual Wins',fontsize=14)
plt.ylabel('Predicted Wins',fontsize=14)
plt.title('Lasso',fontsize=18)
plt.show()

# %% [markdown]
# The model is performing iwth 80% accuracy. Hence we can say that we can predict 80% of the win with the above model

# %% [markdown]
# Lets create our object file for the final model

# %%
import joblib
joblib.dump(ls,'Baseball_win.obj')
# Out:
# ['Baseball_win.obj']
